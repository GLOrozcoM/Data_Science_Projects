# %%
import pandas as pd
import numpy as np

import folium 
from folium import plugins

# %%
from ChernobylUtility import UsefulFunctions as uf

# %%
air = pd.read_csv("air_modified.csv")

# %%
def fill_a_point(index, df):
    """ Fill up a point for the folium map using data for the ith index, and an air data frame. 
    
    index, df -> Dictionary containing results. 
    """
    coordinates = [ df.loc[ index, 'longitude'], df.loc[ index, 'latitude'] ]
    
    begin_wrap = '<h1> '
    end_wrap = ' </h1>'
    city = df.loc[index, 'city']
    country_code = df.loc[index, 'country_code']
    popup = begin_wrap + city + ', ' + country_code + end_wrap
    
    time = df.loc[index, 'Date']
    
    result = { 'coordinates': coordinates, 'popup': popup, 'time': time }
    return result

# %%
def populate_points(df):
    """ Fill up the points list with points following the fill a point format. 
    
    df -> list of points 
    """
    points = []
    for index in range(len(df)):
        single_point = fill_a_point(index, df)
        points.append(single_point)
    return points

# %%
def populate_point_features(dict_points):
    """ Get a list of dictionaries containing separate points from the data. 
    
    list with dictionaries of points -> output a list containing features for the points
    """
    features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': point['coordinates'],
        },
        'properties': {
            'time': point['time'],
            'id':'house',
            'icon': 'circle',
            'popup': point['popup'],
            'iconstyle': {
                'fillColor': 'green',
                'fillOpacity':0.6,
                'stroke':'false',
                'radius':5
            }
        }
    } for point in dict_points
    ]
    return features

# %%
points = populate_points(air)

# %%
features = populate_point_features(points)

# %%
features
# Out:
# [{'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-04-27'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-04-28'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-04-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-04-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-13'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-14'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-15'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-16'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-17'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-18'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-19'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-20'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-21'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-22'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-25'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-26'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-27'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-28'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [55.7, 12.07], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> RISOE, SE </h1>',
#    'time': '1986-05-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-19'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(DWD), DE </h1>',
#    'time': '1986-05-26'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [50.76, 6.1], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> AACHEN(RWTH), DE </h1>',
#    'time': '1986-05-13'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-04-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.3, 10.59], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ANSBACH, DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-04-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-19'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.5, 13.42], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BERLIN-WEST, DE </h1>',
#    'time': '1986-05-26'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-04-29'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [49.2, 12.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> BROTJACKLRIEGEL, DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-13'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-14'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(BZS), DE </h1>',
#    'time': '1986-05-15'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-16'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-23'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [48.0, 7.87], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> FREIBURG(DWD), DE </h1>',
#    'time': '1986-05-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-04-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-13'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-14'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-15'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-16'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GOETTINGEN, DE </h1>',
#    'time': '1986-05-18'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.53, 9.95], 'type': 'Point'},
#   'properties': {'icon': 'circle',
# ...
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-18'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-19'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [53.25, 6.53], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> GRONINGEN, NL </h1>',
#    'time': '1986-05-21'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-01'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [52.76, 4.64], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> PETTEN, NL </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-02'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-16'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-23'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [51.45, 3.58], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> VLISSINGEN, NL </h1>',
#    'time': '1986-05-30'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-03'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-04'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-05'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-06'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-07'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-08'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-09'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-10'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-11'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-12'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-13'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-14'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-15'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-16'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-17'},
#   'type': 'Feature'},
#  {'geometry': {'coordinates': [38.0, 23.78], 'type': 'Point'},
#   'properties': {'icon': 'circle',
#    'iconstyle': {'fillColor': 'green',
#     'fillOpacity': 0.6,
#     'radius': 5,
#     'stroke': 'false'},
#    'id': 'house',
#    'popup': '<h1> ATTIKIS, GR </h1>',
#    'time': '1986-05-18'},
#   'type': 'Feature'},
#  ...]

# %%
features = [
    {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': point['coordinates'],
        },
        'properties': {
            'time': point['time'],
            'id':'house',
            'icon': 'circle',
            'popup': point['popup'],
            'iconstyle': {
                'fillColor': 'green',
                'fillOpacity':0.6,
                'stroke':'false',
                'radius':5
            }
        }
    } for point in points
]
