# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from shapely.geometry import Point, Polygon
import geopandas as gpd

from ChernobylUtility import UsefulFunctions as uf

# %%
shapefile = 'ne_10m_admin_0_countries.shp'
gdf_world = gpd.read_file(shapefile)

# %%
gdf_world.plot()

# %%
air = pd.read_csv('air_modified.csv')

# %%
gdf_air = uf.make_gdf_air(air)

# %%
gdf_air
# Out:
#       Unnamed: 0  Unnamed: 0.1 country_code  Code      city  latitude  \
# 0              0             0           SE     1     RISOE     12.07
# 1              1             1           SE     1     RISOE     12.07
# 2              2             2           SE     1     RISOE     12.07
# 3              3             3           SE     1     RISOE     12.07
# 4              4             4           SE     1     RISOE     12.07
# ...          ...           ...          ...   ...       ...       ...
# 2046        2046          2046           HU    24  BUDAPEST     19.10
# 2047        2047          2047           HU    24  BUDAPEST     19.10
# 2048        2048          2048           HU    24  BUDAPEST     19.10
# 2049        2049          2049           HU    24  BUDAPEST     19.10
# 2050        2050          2050           HU    24  BUDAPEST     19.10
#
#       longitude        Date  endsampling  duration     i131    cs134    cs137  \
# 0          55.7  1986-04-27            0      24.0  1.00000  0.00000  0.24000
# 1          55.7  1986-04-28            0      24.0  0.00460  0.00054  0.00098
# 2          55.7  1986-04-29           12      12.0  0.01470  0.00430  0.00740
# 3          55.7  1986-04-29            0      12.0  0.00061  0.00000  0.00009
# 4          55.7  1986-04-30            0      24.0  0.00075  0.00010  0.00028
# ...         ...         ...          ...       ...      ...      ...      ...
# 2046       47.5  1986-05-07            8      24.0  3.70000  0.58000  1.20000
# 2047       47.5  1986-05-08            8      24.0  2.20000  0.33000  0.69000
# 2048       47.5  1986-05-09            8      24.0  0.75000  0.14000  0.29000
# 2049       47.5  1986-05-10            8      24.0  0.05400  0.00600  0.00900
# 2050       47.5  1986-05-11            8      24.0  0.05100  0.00600  0.01000
#
#                        geometry
# 0     POINT (12.07000 55.70000)
# 1     POINT (12.07000 55.70000)
# 2     POINT (12.07000 55.70000)
# 3     POINT (12.07000 55.70000)
# 4     POINT (12.07000 55.70000)
# ...                         ...
# 2046  POINT (19.10000 47.50000)
# 2047  POINT (19.10000 47.50000)
# 2048  POINT (19.10000 47.50000)
# 2049  POINT (19.10000 47.50000)
# 2050  POINT (19.10000 47.50000)
#
# [2051 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 10))

xlim = ([-12,  42])
ylim = ([34,  72])

ax.set_xlim(xlim)
ax.set_ylim(ylim)

gdf_world.plot(ax = ax, color = 'gray')
gdf_air.plot(ax = ax, markersize = 1, color = 'r', alpha = 0.5)
